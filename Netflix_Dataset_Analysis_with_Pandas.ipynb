# %% [markdown]
# <a href="https://colab.research.google.com/github/arun630-creator/Netflix-Dataset-Analysis-with-pandas/blob/main/Netflix_Dataset_Analysis_with_Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df = pd.read_csv('/netflix_titles.csv')
# Display the first 5 rows to confirm it loaded correctly
display(df.head())
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %%
df.columns
# Out:
# Index(['show_id', 'type', 'title', 'director', 'cast', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'listed_in', 'description'],
#       dtype='object')

# %%
len(df.columns)
# Out:
# 12

# %%
len(df)
# Out:
# 8807

# %%
df.isnull().sum()
# Out:
# show_id            0
# type               0
# title              0
# director        2634
# cast             825
# country          831
# date_added        10
# release_year       0
# rating             4
# duration           3
# listed_in          0
# description        0
# dtype: int64

# %%
df.isnull().sum().sort_values(ascending=False)
# Out:
# director        2634
# country          831
# cast             825
# date_added        10
# rating             4
# duration           3
# show_id            0
# type               0
# title              0
# release_year       0
# listed_in          0
# description        0
# dtype: int64

# %%
# to find max and min missing values column
df.isnull().sum().idxmax()
# df.isnull().sum().idxmin()
# Out:
# 'director'

# %%
df['type'].unique()
# Out:
# array(['Movie', 'TV Show'], dtype=object)

# %%
df['type'].value_counts()
# Out:
# type
# Movie      6131
# TV Show    2676
# Name: count, dtype: int64

# %%
# The original code `df['type'].equals('Movie')` checks if the entire Series is identical to 'Movie', returning a single boolean.
# To count the number of entries where 'type' is 'Movie', use a boolean mask:
(df['type'] == 'Movie').sum()
# Out:
# np.int64(6131)

# %%
# top 10 countries
df['country'].value_counts().head(10)
# Out:
# country
# United States     2818
# India              972
# United Kingdom     419
# Japan              245
# South Korea        199
# Canada             181
# Spain              145
# France             124
# Mexico             110
# Egypt              106
# Name: count, dtype: int64

# %%
df['country'].value_counts().idxmax()
# Out:
# 'United States'

# %%
df.sort_values(by='release_year', ascending=False)
# Out:
#      show_id     type                                          title  \
# 1         s2  TV Show                                  Blood & Water
# 2         s3  TV Show                                      Ganglands
# 3         s4  TV Show                          Jailbirds New Orleans
# 31       s32  TV Show                             Chicago Party Aunt
# 30       s31    Movie                                Ankahi Kahaniya
# ...      ...      ...                                            ...
# 8739   s8740    Movie             Why We Fight: The Battle of Russia
# 8660   s8661    Movie  Undercover: How to Operate Behind Enemy Lines
# 7790   s7791    Movie                                 Prelude to War
# 8205   s8206    Movie                           The Battle of Midway
# 4250   s4251  TV Show              Pioneers: First Women Filmmakers*
#
#                                                director  \
# 1                                                   NaN
# ...

# %%
df['release_year'].max()
# Out:
# 2021

# %%
df['release_year'].min()
# Out:
# 1925

# %%
df[df['release_year']>=2020]
# Out:
#      show_id     type                                      title  \
# 0         s1    Movie                       Dick Johnson Is Dead
# 1         s2  TV Show                              Blood & Water
# 2         s3  TV Show                                  Ganglands
# 3         s4  TV Show                      Jailbirds New Orleans
# 4         s5  TV Show                               Kota Factory
# ...      ...      ...                                        ...
# 7594   s7595    Movie         Norm of the North: Family Vacation
# 8099   s8100    Movie                                Straight Up
# 8125   s8126  TV Show                                Super Wings
# 8132   s8133  TV Show  Surviving R. Kelly Part II: The Reckoning
# 8437   s8438  TV Show                     The Netflix Afterparty
#
#              director                                               cast  \
# 0     Kirsten Johnson                                                NaN
# ...

# %%
len(df[df['release_year']>=2020])
# Out:
# 1545

# %%
df[df['release_year']>=2018]
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8752   s8753    Movie               Wish Man      Theo Davies
# 8756   s8757    Movie              Woodstock    Barak Goodman
# 8774   s8775    Movie              يوم الدين  Abu Bakr Shawky
# 8775   s8776  TV Show        Yeh Meri Family              NaN
# 8803   s8804  TV Show            Zombie Dumb              NaN
#
#                                                    cast  \
# 0                                                   NaN
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...
# ...

# %%
len(df[df['release_year']<2000])
# Out:
# 525

# %%
movies=df[df['type']=='Movie']
movies
# Out:
#      show_id   type                             title  \
# 0         s1  Movie              Dick Johnson Is Dead
# 6         s7  Movie  My Little Pony: A New Generation
# 7         s8  Movie                           Sankofa
# 9        s10  Movie                      The Starling
# 12       s13  Movie                      Je Suis Karl
# ...      ...    ...                               ...
# 8801   s8802  Movie                           Zinzana
# 8802   s8803  Movie                            Zodiac
# 8804   s8805  Movie                        Zombieland
# 8805   s8806  Movie                              Zoom
# 8806   s8807  Movie                            Zubaan
#
#                            director  \
# 0                   Kirsten Johnson
# 6     Robert Cullen, José Luis Ucha
# 7                      Haile Gerima
# 9                    Theodore Melfi
# 12              Christian Schwochow
# ...                             ...
# 8801                Majid Al Ansari
# ...

# %%
df['rating'].value_counts()
# Out:
# rating
# TV-MA       3207
# TV-14       2160
# TV-PG        863
# R            799
# PG-13        490
# TV-Y7        334
# TV-Y         307
# PG           287
# TV-G         220
# NR            80
# G             41
# TV-Y7-FV       6
# NC-17          3
# UR             3
# 74 min         1
# 84 min         1
# 66 min         1
# Name: count, dtype: int64

# %%
df['rating'].value_counts().idxmax()
# Out:
# 'TV-MA'

# %%
df.groupby("type")["release_year"].mean()
# Out:
# type
# Movie      2013.121514
# TV Show    2016.605755
# Name: release_year, dtype: float64

# %%
from google.colab import drive
drive.mount('/content/drive')
